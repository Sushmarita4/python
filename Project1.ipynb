# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushmarita4/python/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Crop_Recommendation.csv')

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 0     202.935536    Rice
# 1     226.655537    Rice
# ...

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      Rainfall  Crop
# 0  202.935536  Rice
# 1  226.655537  Rice
# 2  263.964248  Rice
# 3  242.864034  Rice
# 4  262.717340  Rice

# %%
df.tail()
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 2195  177.774507  Coffee
# 2196  127.924610  Coffee
# 2197  173.322839  Coffee
# 2198  127.175293  Coffee
# 2199  140.937041  Coffee

# %%
df.isnull().sum()
# Out:
# Nitrogen       0
# Phosphorus     0
# Potassium      0
# Temperature    0
# Humidity       0
# pH_Value       0
# Rainfall       0
# Crop           0
# dtype: int64

# %%
df.nunique()
# Out:
# Nitrogen        137
# Phosphorus      117
# Potassium        73
# Temperature    2200
# Humidity       2200
# pH_Value       2200
# Rainfall       2200
# Crop             22
# dtype: int64

# %%
df['Crop'].unique()
# Out:
# array(['Rice', 'Maize', 'ChickPea', 'KidneyBeans', 'PigeonPeas',
#        'MothBeans', 'MungBean', 'Blackgram', 'Lentil', 'Pomegranate',
#        'Banana', 'Mango', 'Grapes', 'Watermelon', 'Muskmelon', 'Apple',
#        'Orange', 'Papaya', 'Coconut', 'Cotton', 'Jute', 'Coffee'],
#       dtype=object)

# %%
df.describe()
# Out:
#           Nitrogen   Phosphorus    Potassium  Temperature     Humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#           pH_Value     Rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df.describe(include=object)
# Out:
#         Crop
# count   2200
# unique    22
# top     Rice
# freq     100

# %%
df.max()
# Out:
# Nitrogen              140
# Phosphorus            145
# Potassium             205
# Temperature     43.675493
# Humidity        99.981876
# pH_Value         9.935091
# Rainfall       298.560117
# Crop           Watermelon
# dtype: object

# %%
df.Crop.value_counts()
# Out:
# Crop
# Rice           100
# Maize          100
# Jute           100
# Cotton         100
# Coconut        100
# Papaya         100
# Orange         100
# Apple          100
# Muskmelon      100
# Watermelon     100
# Grapes         100
# Mango          100
# Banana         100
# Pomegranate    100
# Lentil         100
# Blackgram      100
# MungBean       100
# MothBeans      100
# PigeonPeas     100
# KidneyBeans    100
# ChickPea       100
# Coffee         100
# Name: count, dtype: int64

# %%
sns.distplot(df['Nitrogen'])
# Out:
# <Axes: xlabel='Nitrogen', ylabel='Density'>

# %%
order=df.groupby('Crop').mean().sort_values('Nitrogen',ascending=False).index
plt.figure(figsize=(6,6),dpi=50)
#sns.barplot('Nitrogen','Crop',data=df,order=order)

# %%
df_sorted = df.sort_values('Nitrogen', ascending=False).reset_index()

# Create the bar plot
plt.figure(figsize=(6,6), dpi=50)
sns.barplot(x='Nitrogen', y='Crop', data=df_sorted)
plt.xlabel('Average Nitrogen')
plt.ylabel('Crop')
plt.title('Average Nitrogen by Crop')
plt.show()

# %%
df_sorted = df.sort_values('Temperature', ascending=False).reset_index()

# Create the bar plot
plt.figure(figsize=(6,6), dpi=50)
sns.barplot(x='Temperature', y='Crop', data=df_sorted)
plt.xlabel('Average Temperature')
plt.ylabel('Crop')
plt.title('Average Temperature by Crop')
plt.show()

# %%
df_sorted = df.sort_values('pH_Value', ascending=False).reset_index()

# Create the bar plot
plt.figure(figsize=(6,6), dpi=50)
sns.barplot(x='pH_Value', y='Crop', data=df_sorted)
plt.xlabel('Average pH_Value')
plt.ylabel('Crop')
plt.title('Average pH_Value by Crop')
plt.show()

# %%
df_sorted = df.sort_values('Humidity', ascending=False).reset_index()

# Create the bar plot
plt.figure(figsize=(6,6), dpi=50)
sns.barplot(x='Humidity', y='Crop', data=df_sorted)
plt.xlabel('Average Humidity')
plt.ylabel('Crop')
plt.title('Average Humidity by Crop')
plt.show()

# %%
df_sorted = df.sort_values('Potassium', ascending=False).reset_index()

# Create the bar plot
plt.figure(figsize=(6,6), dpi=50)
sns.barplot(x='Potassium', y='Crop', data=df_sorted)
plt.xlabel('Average Potassium')
plt.ylabel('Crop')
plt.title('Average Potassium by Crop')
plt.show()

# %%
df_sorted = df.sort_values('Temperature', ascending=False).reset_index()

# Create the bar plot
plt.figure(figsize=(6,6), dpi=50)
sns.barplot(x='Temperature', y='Crop', data=df_sorted)
plt.xlabel('Average Temperature')
plt.ylabel('Crop')
plt.title('Average Temperature by Crop')
plt.show()
